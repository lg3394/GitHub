# %%
# Your mission

I recently came across a Spotify playlist called [Fall in a 90s Suburb](https://open.spotify.com/playlist/7r2XnAUl6moWkcwOaWgihD?si=505c8f22f4314a33) while researching the band [SEAGULL SCREAMING KISS HER KISS HER](https://open.spotify.com/artist/1WSO9nf7wTj5DZBsncauGr?si=S0xpngxHR1mLF720lMZwxg). The playlist was pretty good, but since since SSKHKH only has like 1,500 listeners each month I was curious about the most/least popular songs on the playlist.

## My questions

1. What are the ten most popular songs on the playlist?
2. What percentage of them have a popularity of zero? Print them out, sorted by the band name.
3. Is popularity relative to the artist, the album, all songs on Spotify, or something else?

### My suggested approach

I suggest approaching this through the following steps:

1. Getting the playlist and print out its **name and description**. 
2. Print out **the name and popularity of each song**
3. Print out **the name, popularity, and artists** of each track on the playlist. Or, if you'd like a shortcut, just pick the first artist.
4. Instead of printing, use these to **create a new dictionary** each time you look at a track. Print out this dictionary. You should be printing out 476 dictionaries!
5. Printing isn't helpful! Instead, after you create the dictionary **append it** to a list called `all_tracks`
6. When you're done, `all_tracks` should have 476 items in it
7. Sort the list by `popularity`, take the **top ten**
8. Filter the list by `popularity`, selecting only the ones with a popularity of `0`

### Tips

**Spotipy documentation:** https://spotipy.readthedocs.io/

**Spotify Web API documentation:** https://developer.spotify.com/documentation/web-api/

- Do this in many, many cells, not all in one!
- You definitely want to [look at the Spotipy examples](https://github.com/spotipy-dev/spotipy/tree/master/examples) to find some good code to base your answer off of. There are a handful that talk about playlists – it might be helpful to read and compare a few of them!
- Getting the playlist name/description is **a different endpoint** than getting the actual songs on the playlist.
- Are you printing out the **same number of tracks as are in the actual playlist?** Take note and be careful! It should be ~476.
- If you're getting the id of playlist songs but not seeing song names, look for `fields='items.track.id,total` in your code. It's only pulling the track's id! Change it to `items.track,total` and it will return [more information about each track](https://developer.spotify.com/documentation/web-api/reference/get-playlists-tracks)
- `all_tracks = []` should be the first line in your cell. That makes sure it always resets to being empty before you start adding tracks to it.
- Be sure the first and last items in `all_tracks` are different – maybe you're accidentally adding the same item each time!
- Normally we sort lists of numbers, which is easy. Sorting a list of dictionaries can be done easily with `key=`. Look it up!
- Pick the most popular 10 songs using list comprehensions
- Filtering is best done with a list comprehension.
- You can sort by things that aren't numbers!
# Out:
#   Cell In[1], line 3
#     I recently came across a Spotify playlist called [Fall in a 90s Suburb](https://open.spotify.com/playlist/7r2XnAUl6moWkcwOaWgihD?si=505c8f22f4314a33) while researching the band [SEAGULL SCREAMING KISS HER KISS HER](https://open.spotify.com/artist/1WSO9nf7wTj5DZBsncauGr?si=S0xpngxHR1mLF720lMZwxg). The playlist was pretty good, but since since SSKHKH only has like 1,500 listeners each month I was curious about the most/least popular songs on the playlist.
#                                                                  ^
# SyntaxError: invalid decimal literal

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='18e797c9834d443e89b6b95cd96f5662',
    client_secret='2187ac40f4824f62ad605aeb1186ac2e',
))

# %%
data = sp.search(q='playlist:Fall in a 90s Suburb', type='playlist')
data
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=playlist%3AFall+in+a+90s+Suburb&type=playlist&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7jievNUprNUZsZC8vJXnMV'},
#     'href': 'https://api.spotify.com/v1/playlists/7jievNUprNUZsZC8vJXnMV',
#     'id': '7jievNUprNUZsZC8vJXnMV',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#       'width': 60}],
#     'name': 'Fall playlist',
#     'owner': {'display_name': 'Skristal',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ycay9wxbsj82hty6vr3yeuymh'},
#      'href': 'https://api.spotify.com/v1/users/ycay9wxbsj82hty6vr3yeuymh',
#      'id': 'ycay9wxbsj82hty6vr3yeuymh',
#      'type': 'user',
#      'uri': 'spotify:user:ycay9wxbsj82hty6vr3yeuymh'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'OTUsNTRkMjYxMDhiMDM0YmRkNDgyNDM2NTdlNjZlNmYwN2YxNWE2OTZmYg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7jievNUprNUZsZC8vJXnMV/tracks',
#      'total': 92},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7jievNUprNUZsZC8vJXnMV'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2mqGEZC8PoQQs1xIefLMrx'},
#     'href': 'https://api.spotify.com/v1/playlists/2mqGEZC8PoQQs1xIefLMrx',
#     'id': '2mqGEZC8PoQQs1xIefLMrx',
#     'images': [],
#     'name': '',
#     'owner': {'display_name': 'Liam Stephens',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31mtqipjqyy36aobqnxav2heuhv4'},
#      'href': 'https://api.spotify.com/v1/users/31mtqipjqyy36aobqnxav2heuhv4',
#      'id': '31mtqipjqyy36aobqnxav2heuhv4',
#      'type': 'user',
#      'uri': 'spotify:user:31mtqipjqyy36aobqnxav2heuhv4'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'OTUsZTAxZDk4YTA2OTcxN2YxMzU5NWRiMTRjYjI4ZDM1NjZkYTliZWE3OA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2mqGEZC8PoQQs1xIefLMrx/tracks',
#      'total': 0},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2mqGEZC8PoQQs1xIefLMrx'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6NE5dK2TgDOIoY55M3ouNO'},
#     'href': 'https://api.spotify.com/v1/playlists/6NE5dK2TgDOIoY55M3ouNO',
#     'id': '6NE5dK2TgDOIoY55M3ouNO',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb54b339309654dc7becb792cf',
#       'width': None}],
#     'name': "Matt's Playlist",
#     'owner': {'display_name': 'Sturniolo Triplets',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/315fswzkdblniygu2edcdtv7zohq'},
#      'href': 'https://api.spotify.com/v1/users/315fswzkdblniygu2edcdtv7zohq',
#      'id': '315fswzkdblniygu2edcdtv7zohq',
#      'type': 'user',
#      'uri': 'spotify:user:315fswzkdblniygu2edcdtv7zohq'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTMsMjFlMTM1YjZiNzkwYmQ2ZGI5Yjg4MTY3NWM5ZDliZGQ4NTA5ZmExNg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6NE5dK2TgDOIoY55M3ouNO/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6NE5dK2TgDOIoY55M3ouNO'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1dV1wKfsFjjM4h12G8OaWW'},
#     'href': 'https://api.spotify.com/v1/playlists/1dV1wKfsFjjM4h12G8OaWW',
#     'id': '1dV1wKfsFjjM4h12G8OaWW',
#     'images': [],
#     'name': '',
#     'owner': {'display_name': 'Mary ken',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31jvfdzqrnq5wrcwrjfdpcdg7xsi'},
#      'href': 'https://api.spotify.com/v1/users/31jvfdzqrnq5wrcwrjfdpcdg7xsi',
#      'id': '31jvfdzqrnq5wrcwrjfdpcdg7xsi',
#      'type': 'user',
#      'uri': 'spotify:user:31jvfdzqrnq5wrcwrjfdpcdg7xsi'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Mjc3LDNiYWFjZmZkZWNjNjI2NzQyYjIxMWQyNTBhMmNhNzZjNjViZTAxNTc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1dV1wKfsFjjM4h12G8OaWW/tracks',
#      'total': 0},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1dV1wKfsFjjM4h12G8OaWW'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6sd1Rph8eKaWwbP9UdNTY6'},
#     'href': 'https://api.spotify.com/v1/playlists/6sd1Rph8eKaWwbP9UdNTY6',
#     'id': '6sd1Rph8eKaWwbP9UdNTY6',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbf5e675a413ebe4b0e66e405a',
#       'width': None}],
#     'name': 'fall playlist',
#     'owner': {'display_name': 'Gabrielle Scalzo',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/gabby.s14'},
#      'href': 'https://api.spotify.com/v1/users/gabby.s14',
#      'id': 'gabby.s14',
#      'type': 'user',
#      'uri': 'spotify:user:gabby.s14'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODgyLDI5YTZkNTBjN2M2NTIyOWNiMzU1NGI4MWMyMmYwZDM4NzFkYjZmMTY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6sd1Rph8eKaWwbP9UdNTY6/tracks',
#      'total': 347},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6sd1Rph8eKaWwbP9UdNTY6'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6L1MtXNOMuDnTJoy1cxAMI'},
#     'href': 'https://api.spotify.com/v1/playlists/6L1MtXNOMuDnTJoy1cxAMI',
#     'id': '6L1MtXNOMuDnTJoy1cxAMI',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#       'width': 60}],
#     'name': 'Fall ‘24',
#     'owner': {'display_name': 'nicole laeno',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/6medpic040xvsbic237iwyjxi'},
#      'href': 'https://api.spotify.com/v1/users/6medpic040xvsbic237iwyjxi',
#      'id': '6medpic040xvsbic237iwyjxi',
#      'type': 'user',
#      'uri': 'spotify:user:6medpic040xvsbic237iwyjxi'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjAsYTBmZjdlZjI4ZDViZGJjNDI2NzU3OTg1ZDYyZDAxNTY4OThkNzQzZg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6L1MtXNOMuDnTJoy1cxAMI/tracks',
#      'total': 16},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6L1MtXNOMuDnTJoy1cxAMI'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0ujjOglevbkvLXVLVcIFwX'},
#     'href': 'https://api.spotify.com/v1/playlists/0ujjOglevbkvLXVLVcIFwX',
#     'id': '0ujjOglevbkvLXVLVcIFwX',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#       'width': 60}],
#     'name': '',
#     'owner': {'display_name': 'Pantera',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/panteravip'},
#      'href': 'https://api.spotify.com/v1/users/panteravip',
#      'id': 'panteravip',
#      'type': 'user',
#      'uri': 'spotify:user:panteravip'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTIyLGFkNDJhODZhZDBkYWYzMDVlNDM5NWVkMTdlMmQzODQxYWQ4NjI5ZWI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0ujjOglevbkvLXVLVcIFwX/tracks',
#      'total': 107},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0ujjOglevbkvLXVLVcIFwX'},
#    {'collaborative': False,
#     'description': 'With Ally Nicholas, Amira Elfeky, Ana Eclipse and more',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1E8PoV69qYoE6x'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8PoV69qYoE6x',
#     'id': '37i9dQZF1E8PoV69qYoE6x',
#     'images': [{'height': None,
#       'url': 'https://pickasso.spotifycdn.com/image/ab67c0de0000deef/dt/v1/img/radio/track/555rXDsUt8rmNwkWpAPYcW/en',
#       'width': None}],
#     'name': 'Fall Into Radio',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTczMTI4OTk4OCwwMDAwMDAwMDMwNmNmMDE5YmRkYWQxMTFlZTVjMzI2NDBhMTU0YTYw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8PoV69qYoE6x/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1E8PoV69qYoE6x'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1f6kfopjy0uVYzKN9MUVMr'},
#     'href': 'https://api.spotify.com/v1/playlists/1f6kfopjy0uVYzKN9MUVMr',
#     'id': '1f6kfopjy0uVYzKN9MUVMr',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#       'width': 60}],
#     'name': '',
#     'owner': {'display_name': 'mareike009',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/mareike009'},
#      'href': 'https://api.spotify.com/v1/users/mareike009',
#      'id': 'mareike009',
#      'type': 'user',
#      'uri': 'spotify:user:mareike009'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYwMSw0OTkyNTE4ZDljOWZlMWNmZTc4NTM5MTg2MWRhMmQ1N2JkM2NmNTAy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1f6kfopjy0uVYzKN9MUVMr/tracks',
#      'total': 256},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1f6kfopjy0uVYzKN9MUVMr'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1PKYiQbbX3Fak5c9SiYpFQ'},
#     'href': 'https://api.spotify.com/v1/playlists/1PKYiQbbX3Fak5c9SiYpFQ',
#     'id': '1PKYiQbbX3Fak5c9SiYpFQ',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#       'width': 60}],
#     'name': '',
#     'owner': {'display_name': 'Chill Station',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/jxgrydjj6hu5u7seuns0jut6w'},
#      'href': 'https://api.spotify.com/v1/users/jxgrydjj6hu5u7seuns0jut6w',
#      'id': 'jxgrydjj6hu5u7seuns0jut6w',
#      'type': 'user',
#      'uri': 'spotify:user:jxgrydjj6hu5u7seuns0jut6w'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODQ2NSwxZjA0YzkyZTliZWY4ZGUwZjljODNiODEyNzZhOGQ2OWRkMmI1Y2M2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1PKYiQbbX3Fak5c9SiYpFQ/tracks',
#      'total': 4104},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1PKYiQbbX3Fak5c9SiYpFQ'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=playlist%3AFall+in+a+90s+Suburb&type=playlist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 800}}

# %%
data['playlists']['items']
# Out:
# [{'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7jievNUprNUZsZC8vJXnMV'},
#   'href': 'https://api.spotify.com/v1/playlists/7jievNUprNUZsZC8vJXnMV',
#   'id': '7jievNUprNUZsZC8vJXnMV',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733d2dfa42f771cd458b194979ab67616d0000b2739164bafe9aaa168d93f4816aab67616d0000b273d18fa8f63707115cb1b38f65ab67616d0000b273d6839051c4760457e1a60b2a',
#     'width': 60}],
#   'name': 'Fall playlist',
#   'owner': {'display_name': 'Skristal',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ycay9wxbsj82hty6vr3yeuymh'},
#    'href': 'https://api.spotify.com/v1/users/ycay9wxbsj82hty6vr3yeuymh',
#    'id': 'ycay9wxbsj82hty6vr3yeuymh',
#    'type': 'user',
#    'uri': 'spotify:user:ycay9wxbsj82hty6vr3yeuymh'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'OTUsNTRkMjYxMDhiMDM0YmRkNDgyNDM2NTdlNjZlNmYwN2YxNWE2OTZmYg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7jievNUprNUZsZC8vJXnMV/tracks',
#    'total': 92},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7jievNUprNUZsZC8vJXnMV'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2mqGEZC8PoQQs1xIefLMrx'},
#   'href': 'https://api.spotify.com/v1/playlists/2mqGEZC8PoQQs1xIefLMrx',
#   'id': '2mqGEZC8PoQQs1xIefLMrx',
#   'images': [],
#   'name': '',
#   'owner': {'display_name': 'Liam Stephens',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/31mtqipjqyy36aobqnxav2heuhv4'},
#    'href': 'https://api.spotify.com/v1/users/31mtqipjqyy36aobqnxav2heuhv4',
#    'id': '31mtqipjqyy36aobqnxav2heuhv4',
#    'type': 'user',
#    'uri': 'spotify:user:31mtqipjqyy36aobqnxav2heuhv4'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'OTUsZTAxZDk4YTA2OTcxN2YxMzU5NWRiMTRjYjI4ZDM1NjZkYTliZWE3OA==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2mqGEZC8PoQQs1xIefLMrx/tracks',
#    'total': 0},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:2mqGEZC8PoQQs1xIefLMrx'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6NE5dK2TgDOIoY55M3ouNO'},
#   'href': 'https://api.spotify.com/v1/playlists/6NE5dK2TgDOIoY55M3ouNO',
#   'id': '6NE5dK2TgDOIoY55M3ouNO',
#   'images': [{'height': None,
#     'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb54b339309654dc7becb792cf',
#     'width': None}],
#   'name': "Matt's Playlist",
#   'owner': {'display_name': 'Sturniolo Triplets',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/315fswzkdblniygu2edcdtv7zohq'},
#    'href': 'https://api.spotify.com/v1/users/315fswzkdblniygu2edcdtv7zohq',
#    'id': '315fswzkdblniygu2edcdtv7zohq',
#    'type': 'user',
#    'uri': 'spotify:user:315fswzkdblniygu2edcdtv7zohq'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'NTMsMjFlMTM1YjZiNzkwYmQ2ZGI5Yjg4MTY3NWM5ZDliZGQ4NTA5ZmExNg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6NE5dK2TgDOIoY55M3ouNO/tracks',
#    'total': 50},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6NE5dK2TgDOIoY55M3ouNO'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1dV1wKfsFjjM4h12G8OaWW'},
#   'href': 'https://api.spotify.com/v1/playlists/1dV1wKfsFjjM4h12G8OaWW',
#   'id': '1dV1wKfsFjjM4h12G8OaWW',
#   'images': [],
#   'name': '',
#   'owner': {'display_name': 'Mary ken',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/31jvfdzqrnq5wrcwrjfdpcdg7xsi'},
#    'href': 'https://api.spotify.com/v1/users/31jvfdzqrnq5wrcwrjfdpcdg7xsi',
#    'id': '31jvfdzqrnq5wrcwrjfdpcdg7xsi',
#    'type': 'user',
#    'uri': 'spotify:user:31jvfdzqrnq5wrcwrjfdpcdg7xsi'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'Mjc3LDNiYWFjZmZkZWNjNjI2NzQyYjIxMWQyNTBhMmNhNzZjNjViZTAxNTc=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1dV1wKfsFjjM4h12G8OaWW/tracks',
#    'total': 0},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1dV1wKfsFjjM4h12G8OaWW'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6sd1Rph8eKaWwbP9UdNTY6'},
#   'href': 'https://api.spotify.com/v1/playlists/6sd1Rph8eKaWwbP9UdNTY6',
#   'id': '6sd1Rph8eKaWwbP9UdNTY6',
#   'images': [{'height': None,
#     'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbf5e675a413ebe4b0e66e405a',
#     'width': None}],
#   'name': 'fall playlist',
#   'owner': {'display_name': 'Gabrielle Scalzo',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/gabby.s14'},
#    'href': 'https://api.spotify.com/v1/users/gabby.s14',
#    'id': 'gabby.s14',
#    'type': 'user',
#    'uri': 'spotify:user:gabby.s14'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'ODgyLDI5YTZkNTBjN2M2NTIyOWNiMzU1NGI4MWMyMmYwZDM4NzFkYjZmMTY=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6sd1Rph8eKaWwbP9UdNTY6/tracks',
#    'total': 347},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6sd1Rph8eKaWwbP9UdNTY6'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6L1MtXNOMuDnTJoy1cxAMI'},
#   'href': 'https://api.spotify.com/v1/playlists/6L1MtXNOMuDnTJoy1cxAMI',
#   'id': '6L1MtXNOMuDnTJoy1cxAMI',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733daaf47d98ffd6edfcf37b9cab67616d0000b27367103283a4eb57578a428252ab67616d0000b2736f04e53cb5309f8e88286842ab67616d0000b273e2f9df5c00476154a4fbdfff',
#     'width': 60}],
#   'name': 'Fall ‘24',
#   'owner': {'display_name': 'nicole laeno',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/6medpic040xvsbic237iwyjxi'},
#    'href': 'https://api.spotify.com/v1/users/6medpic040xvsbic237iwyjxi',
#    'id': '6medpic040xvsbic237iwyjxi',
#    'type': 'user',
#    'uri': 'spotify:user:6medpic040xvsbic237iwyjxi'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MjAsYTBmZjdlZjI4ZDViZGJjNDI2NzU3OTg1ZDYyZDAxNTY4OThkNzQzZg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6L1MtXNOMuDnTJoy1cxAMI/tracks',
#    'total': 16},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6L1MtXNOMuDnTJoy1cxAMI'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0ujjOglevbkvLXVLVcIFwX'},
#   'href': 'https://api.spotify.com/v1/playlists/0ujjOglevbkvLXVLVcIFwX',
#   'id': '0ujjOglevbkvLXVLVcIFwX',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ce52f4ba340a1e459e6a978ab67616d0000b273347c0a40c1e3f0c890a6d9d6ab67616d0000b273351e5afce42349a9550050deab67616d0000b273d85e0fd554ae1e96ca260f77',
#     'width': 60}],
#   'name': '',
#   'owner': {'display_name': 'Pantera',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/panteravip'},
#    'href': 'https://api.spotify.com/v1/users/panteravip',
#    'id': 'panteravip',
#    'type': 'user',
#    'uri': 'spotify:user:panteravip'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTIyLGFkNDJhODZhZDBkYWYzMDVlNDM5NWVkMTdlMmQzODQxYWQ4NjI5ZWI=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0ujjOglevbkvLXVLVcIFwX/tracks',
#    'total': 107},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0ujjOglevbkvLXVLVcIFwX'},
#  {'collaborative': False,
#   'description': 'With Ally Nicholas, Amira Elfeky, Ana Eclipse and more',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1E8PoV69qYoE6x'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8PoV69qYoE6x',
#   'id': '37i9dQZF1E8PoV69qYoE6x',
#   'images': [{'height': None,
#     'url': 'https://pickasso.spotifycdn.com/image/ab67c0de0000deef/dt/v1/img/radio/track/555rXDsUt8rmNwkWpAPYcW/en',
#     'width': None}],
#   'name': 'Fall Into Radio',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTczMTI4OTk4OCwwMDAwMDAwMDMwNmNmMDE5YmRkYWQxMTFlZTVjMzI2NDBhMTU0YTYw',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E8PoV69qYoE6x/tracks',
#    'total': 50},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1E8PoV69qYoE6x'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1f6kfopjy0uVYzKN9MUVMr'},
#   'href': 'https://api.spotify.com/v1/playlists/1f6kfopjy0uVYzKN9MUVMr',
#   'id': '1f6kfopjy0uVYzKN9MUVMr',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731b3afc4d2223dfda1ececf0eab67616d0000b273b6e40fe3bf6d49b6ef852c79ab67616d0000b273dd8dff82e07684beedab0b47ab67616d0000b273e40ae483c96a0a228055722d',
#     'width': 60}],
#   'name': '',
#   'owner': {'display_name': 'mareike009',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mareike009'},
#    'href': 'https://api.spotify.com/v1/users/mareike009',
#    'id': 'mareike009',
#    'type': 'user',
#    'uri': 'spotify:user:mareike009'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'MTYwMSw0OTkyNTE4ZDljOWZlMWNmZTc4NTM5MTg2MWRhMmQ1N2JkM2NmNTAy',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1f6kfopjy0uVYzKN9MUVMr/tracks',
#    'total': 256},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1f6kfopjy0uVYzKN9MUVMr'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1PKYiQbbX3Fak5c9SiYpFQ'},
#   'href': 'https://api.spotify.com/v1/playlists/1PKYiQbbX3Fak5c9SiYpFQ',
#   'id': '1PKYiQbbX3Fak5c9SiYpFQ',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273039ae3d5aa7049254e794115ab67616d0000b27362892cd7493a46100ed78debab67616d0000b2739d0dfcfbc8b90be59c48d3caab67616d0000b273dc0f1e9220077944f11134a0',
#     'width': 60}],
#   'name': '',
#   'owner': {'display_name': 'Chill Station',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/jxgrydjj6hu5u7seuns0jut6w'},
#    'href': 'https://api.spotify.com/v1/users/jxgrydjj6hu5u7seuns0jut6w',
#    'id': 'jxgrydjj6hu5u7seuns0jut6w',
#    'type': 'user',
#    'uri': 'spotify:user:jxgrydjj6hu5u7seuns0jut6w'},
#   'primary_color': None,
#   'public': None,
#   'snapshot_id': 'ODQ2NSwxZjA0YzkyZTliZWY4ZGUwZjljODNiODEyNzZhOGQ2OWRkMmI1Y2M2',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1PKYiQbbX3Fak5c9SiYpFQ/tracks',
#    'total': 4104},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1PKYiQbbX3Fak5c9SiYpFQ'}]

# %%
name = data['playlists']['items'][0]['name']
description = data['playlists']['items'][0]['description']
name, description
# Out:
# ('Fall playlist', '')

# %%
playlist_id = "7r2XnAUl6moWkcwOaWgihD"
playlist = sp.playlist(playlist_id)
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
playlist['description']
print (f"Playlist description: {playlist['description']}")
# Out:
# Playlist description: fuzzy guitars from the 80s, 90s &amp; early 00s for feeling angsty as the seasons change.  put on a sweater and listen to some indie rock, shoegaze, and noisy twee.

# %%
playlist['tracks']['items'][0]['track']['name']
for song_item in tracks:
    song = song_item['track']  
    song_name = song['name'] 
    song_popularity = song['popularity']
    print(f"Song Name: {song_name}, Popularity: {song_popularity}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 2
#       1 playlist = sp.playlist_tracks(playlist_id, fields='items.track,total', additional_types=['track'])
# ----> 2 playlist['tracks']['items'][0]['track']['name']
#       3 for song_item in tracks:
#       4     song = song_item['track']
#
# KeyError: 'tracks'

# %%
all_tracks = []

for item in playlist['tracks']['items']:
    track = item['track']
    track_info = {
        'name': track['name'],
        'popularity': track['popularity'],
        'artist': track['artists'][0]['name'],  # Get the first artist
    }
    all_tracks.append(track_info)

# %%
print(f"Total Tracks: {len(all_tracks)}")
# Out:
# Total Tracks: 100

# %%
top_10_tracks = sorted(all_tracks, key=lambda x: x['popularity'], reverse=True)[:10]
print("\nTop 10 Most Popular Songs:")
for track in top_10_tracks:
    print(f"{track['name']} by {track['artist']} (Popularity: {track['popularity']})")
# Out:
# Top 10 Most Popular Songs:
# Drown by The Smashing Pumpkins (Popularity: 60)
# When You Sleep by my bloody valentine (Popularity: 59)
# Feel the Pain by Dinosaur Jr. (Popularity: 49)
# Paper Thin Walls by Modest Mouse (Popularity: 46)
# Scott Pilgrim by Plumtree (Popularity: 44)
# Sick of Myself by Matthew Sweet (Popularity: 40)
# Hey Sandy by Polaris (Popularity: 36)
# Number One Blind by Veruca Salt (Popularity: 35)
# All the Umbrellas in London by The Magnetic Fields (Popularity: 35)
# Get Back by Veruca Salt (Popularity: 34)

# %%
zero_popularity_tracks = [track for track in all_tracks if track['popularity'] == 0]
print("\nTracks with Popularity of 0:")
for track in sorted(zero_popularity_tracks, key=lambda x: x['artist']):
    print(f"{track['name']} by {track['artist']}")
# Out:
# Tracks with Popularity of 0:
# Get Me Away From Here, I'm Dying by Belle and Sebastian
# Sleep The Clock Around by Belle and Sebastian
# Lazy Heart by Black Tambourine
# Throw Aggi Off the Bridge by Black Tambourine
# Fling by Built To Spill
# Bluebeard - Remastered 2006 by Cocteau Twins
# Rose Parade by Elliott Smith
# Ballad Of Big Nothing by Elliott Smith
# A.M. 180 by Grandaddy
# The Best Of Jill Hives by Guided By Voices
# Don’t Stop Now by Guided By Voices
# Sweetness and Light by Lush
# 16 by Noise Addict
# Boyfriendship by Noise Addict
# Throwing Back the Apple by Pale Saints
# Frontwards by Pavement
# Nail Clinic by Pavement
# Box Elder by Pavement
# Elevate Me Later by Pavement
# Stereo by Pavement
# Tripoli by Pinback
# Gouge Away by Pixies
# Rebound - Remastered by Sebadoh
# Post-Paint Boy by Stephen Malkmus
# The Light That Will Cease To Fail by Stereolab
# John Cage Bubblegum by Stereolab
# International Colouring Contest by Stereolab
# Cybele's Reverie by Stereolab
# Tone Burst [Country] by Stereolab
# Seed Toss by Superchunk
# Skip Steps 1 & 3 by Superchunk
# Everything Flows by Teenage Fanclub
# First Revival by The Amps
# Fortunately Gone by The Breeders
# Cannonball by The Breeders
# Don't Call Home by The Breeders
# Into Your Arms by The Lemonheads
# Born on a Train by The Magnetic Fields
# Know Your Onion! by The Shins
# My Broken Heart by Tiger Trap
# Marzipan by Velocity Girl
# Barnaby, Hardly Working by Yo La Tengo
# Big Sky by Yo La Tengo
# Cherry Chapstick by Yo La Tengo
# Fog Over Frisco by Yo La Tengo
# Decora by Yo La Tengo
# Season of the Shark by Yo La Tengo
# Sleeping in the Beetle Bug by of Montreal
# I Can't Stop Your Memory by of Montreal

# %%
# 3. Is popularity relative to the artist, the album, all songs on Spotify, or something else?

# %%
# It is calculated relative to all songs on Spotify.
